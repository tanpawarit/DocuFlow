# %%
import base64
import os
from mistralai import Mistral
from src.utils.config import get_config_value

mistral_token = get_config_value("mistral")
api_key = mistral_token.get("token") 

def encode_image(image_path):
    """Encode the image to base64."""
    try:
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')
    except FileNotFoundError:
        print(f"Error: The file {image_path} was not found.")
        return None
    except Exception as e:  # Added general exception handling
        print(f"Error: {e}")
        return None

def main(): 
    client = Mistral(api_key=api_key)
    ocr_response = client.ocr.process(
        model="mistral-ocr-latest",
        document={
            "type": "image_url",
            "image_url": f"data:image/jpeg;base64,{encode_image("/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes/credit_note_1.png")}" 
        },
        include_image_base64=True
    )
    return ocr_response
    # with open("test.md", "w") as f:
    #     f.write(ocr_response.pages[0].markdown)

if __name__ == "__main__":
    ocr_response = main()

# %%
print(ocr_response.pages[0].markdown)
# Out:
# # บริษัท โกลบอล โลจิสติกส์ โซลูชั่นส์
#
# 999/9 อาคารคี ออฟฟิศเคส แอท เซ็นทรัลเวิลด์ ชั้น 40 ถ.พระราม 1 แขวงปทุมวัน เขตปทุมวัน กรุงเทพฯ 10330 โทร: 02-123-4567 เลขประจำตัวผู้เสียภาษี: 0879189666478
#
# ลูกค้า: หจก. สยามการพิมพ์ ที่อยู่: 101 อาคารทรู ศิริทัล พารค ชั้น 7 ถ.สุขุมวิท แขวงบางจาก เขตพระพุทธ กรุงเทพฯ 103984/2025
#
# เรียน: คุณสุนีย์ โทร: 02-123-4567 เลขประจำตัวผู้เสียภาษี: 0560437188559
#
# |  ลำดับ รายการ | จำนวน | ราคา/หน่วย | จำนวนเงิน  |
# | --- | --- | --- | --- |
# |  1 บริการที่ปรึกษาคำแถวรดลาดศิริทัล (เดือน มี.ย.) | 1 | 30,000.00 | 30,000.00  |
# |  2 คาบำรุงรักษาระบบรายปี | 1 | 20,000.00 | 20,000.00  |
# |  3 คาเขา Cloud Server - Business Package | 3 | 2,500.00 | 7,500.00  |
# |  4 พัฒนาและออกแบบเว็บไซต์ (E-commerce) | 1 | 75,000.00 | 75,000.00  |
# |  เรียนโขการข้าระเงิน: ข้าระพันทิเมื่อโต่วันเอกสาร ข้อมูลการโอนเงิน: ธ.กติกริไทย บัญชีออมทรัพย์ 012-3-45678-9 | ยอดรวม (Subtotal) | 132,500.00 |   |
# |   | ภาษีมูลค่าเพิ่ม (VAT 7%) | 9,275.00 |   |
# |   | ยอดข้าระทั้งสิ้น | 141,775.00 |   |
#
# ผู้อนุมัติ
#
# ผู้รับเงิน / ผู้ลงของ

# %%
# !pip install typhoon-ocr 
# brew install poppler
from typhoon_ocr import ocr_document

# Or with image
markdown = ocr_document(
    pdf_or_image_path="/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes/credit_note_1.png",  # Works with PDFs or images
    task_type="structure",    # Choose between "default" or "structure"
    page_num=1,
    api_key="sk-6UqhbIzqwx3SlQBy12ufkIoMSkILFZWWPgbdvRjxb9RtJbQ1"
)

# %%
from IPython.display import Markdown, display

display(Markdown(markdown))
# Out:
# บริษัท โกลบอล เลสิติกส์ โซลูชั่นส์
#
# ใบสดหนี้
# 99/9 อาคารดี ออฟฟิศเตค แอนด์ พื้นที่จัดแสดง สัง 40 ถ.พระราม 1 แขวงปทุมวัน เขตปทุมวัน กรุงเทพฯ 10330
# โทร. 02-123-4567 เลขประจำตัวผู้เสียภาษี 0379189666478
#
# ลูกค้า: พกง.สยามการพิมพ์
# เลขที่
# AC-2025-4837
#
# ที่อยู่: 101 อาคารกรุงธน ซีเน็คทาวร์ ฟาร์ค ชั้น 7 กรุงธนิเวศน์ แขวงบางจาก เขตบางกะปิ กรุงเทพฯ 10250/4,2025
# เป็นต. กบุญยืน โทร. 02-123-4567
# เลขประจำตัวผู้เสียภาษี 0360437188559
# <table>
# <tr>
# <th colspan="2">ลำดับรายการ</th>
# <th>จำนวน</th>
# <th>ราคา/หน่วย</th>
# <th>จำนวนเงิน</th>
# </tr>
# <tr>
# <td>1</td>
# <td>บริการให้เช่าพื้นที่สำหรับจัดงานประชุม (เดือน มิ.ย.)</td>
# <td>1</td>
# <td>30,000.00</td>
# <td>30,000.00</td>
# </tr>
# <tr>
# <td>2</td>
# <td>ดำเนินกิจการระบบรายปี</td>
# <td>1</td>
# <td>20,000.00</td>
# <td>20,000.00</td>
# </tr>
# <tr>
# <td>3</td>
# <td>อาเซา Cloud Server - Business Package</td>
# <td>3</td>
# <td>2,500.00</td>
# <td>7,500.00</td>
# </tr>
# <tr>
# <td>4</td>
# <td>พัฒนาและออกแบบเว็บไซต์ (E-commerce)</td>
# <td>1</td>
# <td>75,000.00</td>
# <td>75,000.00</td>
# </tr>
# </table>
# เรื่องใช้การชำระเงิน : ชำระทันทีเมื่อได้รับเอกสาร
# ข้อมูลการโอนเงิน: ธ.กสิกรไทย บัญชีออมทรัพย์ 012-3-45678-9
#
# ยอดรวม (Subtotal)
# 132,500.00
#
# ภาษีมูลค่าเพิ่ม (VAT 7%)
# 9,275.00
#
# ยอดชำระทั้งสิ้น
# 141,775.00
#
# ผู้อนุมัติ
#
# ผู้รับเงิน / ผู้ดำรง

# %%
# !uv pip install agentic-doc
# Out:
# Audited 1 package in 1ms

# %%
import os
  
os.environ["VISION_AGENT_API_KEY"] = "ZTVrc2JiamN0MDA5ZGprbHh6MmdtOlFSdTZhVlFKcGo2cDBuYjBOYm1uZWY2QlQzd21nZ1Zo"
os.environ["GOOGLE_API_KEY"] = "AIzaSyA_cJAOFVHZ8npAP_zHP3yQmfIj6tiOrcE"

# %%
from agentic_doc.parse import parse

# Parse a local file
result = parse("/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes/credit_note_1.png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 from agentic_doc.parse import parse
#       3 # Parse a local file
#       4 result = parse("/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes/credit_note_1.png")
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/agentic_doc/parse.py:30
#      20 from agentic_doc.common import (
#      21     Document,
#      22     PageError,
#    (...)     27     create_metadata_model,
#      28 )
#      29 from agentic_doc.config import Settings, get_settings, ParseConfig
# ---> 30 from agentic_doc.connectors import BaseConnector, ConnectorConfig, create_connector
#      31 from agentic_doc.utils import (
#      32     check_endpoint_and_api_key,
#      33     download_file,
#    (...)     38     split_pdf,
#      39 )
#      41 _LOGGER = structlog.getLogger(__name__)
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/agentic_doc/connectors.py:22
#      20 from google.oauth2.credentials import Credentials
#      21 from google_auth_oauthlib.flow import InstalledAppFlow  # type: ignore
# ---> 22 from googleapiclient.discovery import build  # type: ignore
#      23 from googleapiclient.discovery import Resource
#      24 from googleapiclient.http import MediaIoBaseDownload  # type: ignore
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/googleapiclient/discovery.py:42
#      39 import re
#      40 import urllib
# ---> 42 import google.api_core.client_options
#      43 from google.auth.exceptions import MutualTLSChannelError
#      44 from google.auth.transport import mtls
#
# ModuleNotFoundError: No module named 'google.api_core'

# %%
# !pip install google-api-core
# Out:
# Requirement already satisfied: google-api-core in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (2.25.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core) (2.40.3)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-api-core) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core) (2025.6.15)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/pawarison/.pyenv/versions/3.12.4/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core) (0.6.1)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from agentic_doc.parse import parse
from agentic_doc.connectors import LocalConnectorConfig

config = LocalConnectorConfig()

# Parse all supported documents in a directory
results = parse(config, connector_path="/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes")

# Parse with pattern filtering
results = parse(config, connector_path="/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes", connector_pattern="*.pdf")

# Parse all supported documents in a directory recursively (search subdirectories as well)
config = LocalConnectorConfig(recursive=True)
results = parse(config, connector_path="/path/to/documents")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 from agentic_doc.parse import parse
#       2 from agentic_doc.connectors import LocalConnectorConfig
#       4 config = LocalConnectorConfig()
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/agentic_doc/parse.py:30
#      20 from agentic_doc.common import (
#      21     Document,
#      22     PageError,
#    (...)     27     create_metadata_model,
#      28 )
#      29 from agentic_doc.config import Settings, get_settings, ParseConfig
# ---> 30 from agentic_doc.connectors import BaseConnector, ConnectorConfig, create_connector
#      31 from agentic_doc.utils import (
#      32     check_endpoint_and_api_key,
#      33     download_file,
#    (...)     38     split_pdf,
#      39 )
#      41 _LOGGER = structlog.getLogger(__name__)
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/agentic_doc/connectors.py:22
#      20 from google.oauth2.credentials import Credentials
#      21 from google_auth_oauthlib.flow import InstalledAppFlow  # type: ignore
# ---> 22 from googleapiclient.discovery import build  # type: ignore
#      23 from googleapiclient.discovery import Resource
#      24 from googleapiclient.http import MediaIoBaseDownload  # type: ignore
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/googleapiclient/discovery.py:42
#      39 import re
#      40 import urllib
# ---> 42 import google.api_core.client_options
#      43 from google.auth.exceptions import MutualTLSChannelError
#      44 from google.auth.transport import mtls
#
# ModuleNotFoundError: No module named 'google.api_core'

# %%
from vision_agent.agent import VisionAgentCoderV2
from vision_agent.models import AgentMessage

# Enable verbose output 
agent = VisionAgentCoderV2(verbose=True)

# Add your prompt (content) and image file (media)
code_context = agent.generate_code(
    [
        AgentMessage(
            role="user",
            content="Describe the image",
            media=["/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes/credit_note_1.png"]
        )
    ]
)

# Write the output to a file
with open("generated_code.py", "w") as f:
    f.write(code_context.code + "\n" + code_context.test)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[28], line 8
#
#       5 agent = VisionAgentCoderV2(verbose=True)
#
#       7 # Add your prompt (content) and image file (media)
#
# ----> 8 code_context = agent.generate_code(
#
#       9     [
#
#      10         AgentMessage(
#
#      11             role="user",
#
#      12             content="Describe the image",
#
#      13             media=["/Users/pawarison/dev/DocuFlow/data/synthetic_data/credit_notes/credit_note_1.png"]
#
#      14         )
#
#      15     ]
#
#      16 )
#
#      18 # Write the output to a file
#
#      19 with open("generated_code.py", "w") as f:
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/vision_agent/agent/vision_agent_coder_v2.py:408, in VisionAgentCoderV2.generate_code(self, chat, max_steps, code_interpreter)
#
#     402 with (
#
#     403     CodeInterpreterFactory.new_instance(self.code_sandbox_runtime)
#
#     404     if code_interpreter is None
#
#     405     else code_interpreter
#
#     406 ) as code_interpreter:
#
#     407     int_chat, orig_chat, _ = add_media_to_chat(chat, code_interpreter)
#
# --> 408     plan_context = self.planner.generate_plan(
#
#     409         int_chat, max_steps=max_steps, code_interpreter=code_interpreter
#
#     410     )
#
#     411     # the planner needs an interaction, so return before generating code
#
#     412     if isinstance(plan_context, InteractionContext):
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/vision_agent/agent/vision_agent_planner_v2.py:544, in VisionAgentPlannerV2.generate_plan(self, chat, max_steps, code_interpreter)
#
#     540     response = run_multi_trial_planning(
#
#     541         int_chat, media_list, self.planner
#
#     542     )
#
#     543 else:
#
# --> 544     response = run_planning(int_chat, media_list, self.planner)
#
#     546 response = response_safeguards(response)
#
#     547 thinking = extract_tag(response, "thinking")
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/vision_agent/agent/vision_agent_planner_v2.py:120, in run_planning(chat, media_list, model)
#
#     117 if chat[-1].role == "observation" and chat[-1].media is not None:
#
#     118     message["media"] = chat[-1].media
#
# --> 120 response = model.chat([message])
#
#     121 return cast(str, response)
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/vision_agent/lmm/lmm.py:450, in AnthropicLMM.chat(self, chat, **kwargs)
#
#     448 # prefers kwargs from second dictionary over first
#
#     449 tmp_kwargs = self.kwargs | kwargs
#
# --> 450 response = self.client.messages.create(
#
#     451     model=self.model_name, messages=messages, **tmp_kwargs
#
#     452 )
#
#     453 if "stream" in tmp_kwargs and tmp_kwargs["stream"]:
#
#     455     def f() -> Iterator[Optional[str]]:
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#
#     276     raise TypeError(msg)
#
# --> 277 return func(*args, **kwargs)
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/resources/messages.py:902, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#
#     868 @required_args(["max_tokens", "messages", "model"], ["max_tokens", "messages", "model", "stream"])
#
#     869 def create(
#
#     870     self,
#
#    (...)    900     timeout: float | httpx.Timeout | None | NotGiven = 600,
#
#     901 ) -> Message | Stream[RawMessageStreamEvent]:
#
# --> 902     return self._post(
#
#     903         "/v1/messages",
#
#     904         body=maybe_transform(
#
#     905             {
#
#     906                 "max_tokens": max_tokens,
#
#     907                 "messages": messages,
#
#     908                 "model": model,
#
#     909                 "metadata": metadata,
#
#     910                 "stop_sequences": stop_sequences,
#
#     911                 "stream": stream,
#
#     912                 "system": system,
#
#     913                 "temperature": temperature,
#
#     914                 "tool_choice": tool_choice,
#
#     915                 "tools": tools,
#
#     916                 "top_k": top_k,
#
#     917                 "top_p": top_p,
#
#     918             },
#
#     919             message_create_params.MessageCreateParams,
#
#     920         ),
#
#     921         options=make_request_options(
#
#     922             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#
#     923         ),
#
#     924         cast_to=Message,
#
#     925         stream=stream or False,
#
#     926         stream_cls=Stream[RawMessageStreamEvent],
#
#     927     )
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#
#    1252 def post(
#
#    1253     self,
#
#    1254     path: str,
#
#    (...)   1261     stream_cls: type[_StreamT] | None = None,
#
#    1262 ) -> ResponseT | _StreamT:
#
#    1263     opts = FinalRequestOptions.construct(
#
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#
#    1265     )
#
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#
#     933 def request(
#
#     934     self,
#
#     935     cast_to: Type[ResponseT],
#
#    (...)    940     stream_cls: type[_StreamT] | None = None,
#
#     941 ) -> ResponseT | _StreamT:
#
# --> 942     return self._request(
#
#     943         cast_to=cast_to,
#
#     944         options=options,
#
#     945         stream=stream,
#
#     946         stream_cls=stream_cls,
#
#     947         remaining_retries=remaining_retries,
#
#     948     )
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:968, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#
#     965 options = self._prepare_options(options)
#
#     967 retries = self._remaining_retries(remaining_retries, options)
#
# --> 968 request = self._build_request(options)
#
#     969 self._prepare_request(request)
#
#     971 kwargs: HttpxSendArgs = {}
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:461, in BaseClient._build_request(self, options)
#
#     458     else:
#
#     459         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
#
# --> 461 headers = self._build_headers(options)
#
#     462 params = _merge_mappings(self.default_query, options.params)
#
#     463 content_type = headers.get("Content-Type")
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:416, in BaseClient._build_headers(self, options)
#
#     414 custom_headers = options.headers or {}
#
#     415 headers_dict = _merge_mappings(self.default_headers, custom_headers)
#
# --> 416 self._validate_headers(headers_dict, custom_headers)
#
#     418 # headers are case-insensitive while dictionaries are not.
#
#     419 headers = httpx.Headers(headers_dict)
#
#
#
# File ~/dev/DocuFlow/.venv/lib/python3.12/site-packages/anthropic/_client.py:192, in Anthropic._validate_headers(self, headers, custom_headers)
#
#     189 if isinstance(custom_headers.get("Authorization"), Omit):
#
#     190     return
#
# --> 192 raise TypeError(
#
#     193     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#
#     194 )
#
#
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
